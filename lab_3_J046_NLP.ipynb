# %%
import pandas as pd
import numpy as np 
import re

# %%
df=pd.read_csv("date_parser_testcases.csv")

# %%
df.head()
# Out:
#                                                Input Expected Output
# 0        The event will take place on March 5, 2023.      05/03/2023
# 1                     Her birthday is on 07/08/1990.      07/08/1990
# 2                        The deadline is 2022-12-31.      31/12/2022
# 3                     We met on 1st of January 2000.      01/01/2000
# 4  The concert is scheduled for 15th September, 2...      15/09/2021

# %%
df.head(50)
# Out:
#                                                 Input Expected Output
# 0         The event will take place on March 5, 2023.      05/03/2023
# 1                      Her birthday is on 07/08/1990.      07/08/1990
# 2                         The deadline is 2022-12-31.      31/12/2022
# 3                      We met on 1st of January 2000.      01/01/2000
# 4   The concert is scheduled for 15th September, 2...      15/09/2021
# 5                       Let's catch up on 02.04.2022.      02/04/2022
# 6                      The project started on 5/6/19.      05/06/2019
# 7                          He was born on 1987/11/23.      23/11/1987
# 8                      Christmas is on 25th Dec 2024.      25/12/2024
# 9              The meeting is set for April 03, 2020.      03/04/2020
# 10  Her birthdate, noted as 1997-05-20, is in the ...      20/05/1997
# 11      Her appointment is on the 2nd of March, 2021.      02/03/2021
# 12                       The exam date is 2021.11.10.      10/11/2021
# 13                      They got married on 12/12/12.      12/12/2012
# 14            The workshop is on February 15th, 2022.      15/02/2022
# 15                  Submit your report by 08/31/2021.      31/08/2021
# 16                The course starts on 1st July 2023.      01/07/2023
# 17          Independence Day is on 4th of July, 2022.      04/07/2022
# 18                        His birthday is 1995/10/30.      30/10/1995
# 19                 The new year begins on 01-01-2023.      01/01/2023
# 20                      The seminar is on 03/14/2022.      14/03/2022
# 21                         My last day is 31.08.2020.      31/08/2020
# 22                        The due date is 2020-02-28.      28/02/2020
# 23              The holiday starts on Dec 20th, 2021.      20/12/2021
# 24       The conference will be held on 5th May 2023.      05/05/2023
# 25                       They moved in on 12/25/2019.      25/12/2019
# 26             The festival begins on March 17, 2022.      17/03/2022
# 27                     The ceremony is on 11.11.2021.      11/11/2021
# 28                        The event is on 2023/07/04.      04/07/2023
# 29               Her graduation is on May 30th, 2022.      30/05/2022
# 30                    The release date is 2021-09-09.      09/09/2021
# 31                      The interview is on 1/2/2022.      01/02/2022
# 32                  The celebration is on 2022-10-10.      10/10/2022
# 33             His wedding is on 6th of August, 2020.      06/08/2020
# 34                    She was born on 3rd March 1998.      03/03/1998
# 35                      The opening is on 10/10/2018.      10/10/2018
# 36                        The deadline is 2020.12.15.      15/12/2020
# 37                        The party is on 31-12-2022.      31/12/2022
# 38              The workshop is on February 29, 2024.      29/02/2024
# 39                     Vacation starts on 07/15/2021.      15/07/2021
# 40              The application is due by 2022-03-03.      03/03/2022
# 41               The tournament is on June 1st, 2021.      01/06/2021
# 42                    The closing date is 08/08/2020.      08/08/2020
# 43                      The concert is on 2020/09/09.      09/09/2020
# 44                         The exam is on 01.01.2022.      01/01/2022
# 45                    Independence Day is 2023-07-04.      04/07/2023
# 46               The last date is 30th November 2022.      30/11/2022
# 47            The conference is on 15th October 2023.      15/10/2023
# 48                       His birthdate is 1990-05-20.      20/05/1990
# 49               The festival is on 12th August 2024.      12/08/2024

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                 Input Expected Output
# 0         The event will take place on March 5, 2023.      05/03/2023
# 1                      Her birthday is on 07/08/1990.      07/08/1990
# 2                         The deadline is 2022-12-31.      31/12/2022
# 3                      We met on 1st of January 2000.      01/01/2000
# 4   The concert is scheduled for 15th September, 2...      15/09/2021
# ..                                                ...             ...
# 95  We celebrate Independence Day on 2023-07-04, a...      04/07/2023
# 96  The final date for submission is 30th November...      30/11/2022
# 97  The annual conference is on 15th October 2023,...      15/10/2023
# 98  His birthdate, noted as 1990-05-20, is in the ...      20/05/1990
# 99  The festival will be celebrated on 12th August...      12/08/2024
#
# [100 rows x 2 columns]>

# %%
df.isna().sum()
# Out:
# Input              0
# Expected Output    0
# dtype: int64

# %%
#to convert month names to numbers
def month_name_to_number(month):
    month_dict = {
        'january': '01', 'february': '02', 'march': '03', 'april': '04',
        'may': '05', 'june': '06', 'july': '07', 'august': '08',
        'september': '09', 'october': '10', 'november': '11', 'december': '12'
    }
    return month_dict.get(month.lower(), None)

# %%
def extract_date(text):
    # Define regex patterns for different date formats
    patterns = [
        r'(\d{1,2})(st|nd|rd|th)?[\s\-]*(of)?[\s\-]*(\b\w+\b)[\s\-,]*(\d{4})',  # 1st of January 2000, 15th September, 2021
        r'(\d{4})[\-\/\.](\d{2})[\-\/\.](\d{2})',  # 2022-12-31, 2022.12.31
        r'(\d{1,2})[\-\/\.](\d{1,2})[\-\/\.](\d{4})',  # 07/08/1990, 07.08.1990
        r'(\b\w+\b)[\s\-]*(\d{1,2})(st|nd|rd|th)?[\s\-,]*(\d{4})'  # March 5, 2023
    ]
    
    for pattern in patterns:
        match = re.search(pattern, text)
        if match:
            if len(match.groups()) == 5:  # Handle formats with month names
                day = match.group(1).zfill(2)
                month = month_name_to_number(match.group(4) if match.group(4) else match.group(3))
                year = match.group(5)
                return f"{day}/{month}/{year}" if month else None
            elif len(match.groups()) == 3:  # Handle formats like 2022-12-31
                year, month, day = match.group(1), match.group(2).zfill(2), match.group(3).zfill(2)
                return f"{day}/{month}/{year}"
            elif len(match.groups()) == 4:  # Handle formats like 07/08/1990
                day, month, year = match.group(1).zfill(2), match.group(2).zfill(2), match.group(3)
                return f"{day}/{month}/{year}"
    
    # If no patterns match, return None
    return None

# %%
# Apply the function to the dataset
df['Parsed Date'] = df['Input'].apply(extract_date)

# %%
# Compare with the expected output
df['Match'] = df['Parsed Date'] == df['Expected Output']

# %%
# Output the results
incorrect_rows = df[df['Match'] == False]
print(f"Number of incorrect rows: {len(incorrect_rows)}")
print("\nIncorrectly parsed dates:")
print(incorrect_rows[['Input', 'Expected Output', 'Parsed Date']])
# Out:
# Number of incorrect rows: 52
#
# Incorrectly parsed dates:
#                                                 Input  Expected Output  \
# 0         The event will take place on March 5, 2023.       05/03/2023
# 1                      Her birthday is on 07/08/1990.       07/08/1990
# 5                       Let's catch up on 02.04.2022.       02/04/2022
# 6                      The project started on 5/6/19.       05/06/2019
# 8                      Christmas is on 25th Dec 2024.       25/12/2024
# 9              The meeting is set for April 03, 2020.       03/04/2020
# 13                      They got married on 12/12/12.       12/12/2012
# 14            The workshop is on February 15th, 2022.       15/02/2022
# 15                  Submit your report by 08/31/2021.       31/08/2021
# 19                 The new year begins on 01-01-2023.       01/01/2023
# 20                      The seminar is on 03/14/2022.       14/03/2022
# 21                         My last day is 31.08.2020.       31/08/2020
# 23              The holiday starts on Dec 20th, 2021.       20/12/2021
# 25                       They moved in on 12/25/2019.       25/12/2019
# 26             The festival begins on March 17, 2022.       17/03/2022
# 27                     The ceremony is on 11.11.2021.       11/11/2021
# 29               Her graduation is on May 30th, 2022.       30/05/2022
# 31                      The interview is on 1/2/2022.       01/02/2022
# 35                      The opening is on 10/10/2018.       10/10/2018
# 37                        The party is on 31-12-2022.       31/12/2022
# 38              The workshop is on February 29, 2024.       29/02/2024
# 39                     Vacation starts on 07/15/2021.       15/07/2021
# 41               The tournament is on June 1st, 2021.       01/06/2021
# 42                    The closing date is 08/08/2020.       08/08/2020
# 44                         The exam is on 01.01.2022.       01/01/2022
# 50                                              Input  Expected Output
# 51  We are planning to meet on March 5, 2023, for ...       05/03/2023
# 52  Her birthday, which she celebrates on 07/08/19...       07/08/1990
# 56   Remember, the meeting is on 02.04.2022 at 10 AM.       02/04/2022
# 57  Let's wrap up the project by 5/6/19, so we can...       05/06/2019
# 59  We celebrate Christmas every year on 25th Dec,...       25/12/2024
# 60  The meeting is rescheduled to April 03, 2020, ...       03/04/2020
# 63  They celebrated their wedding on 12/12/12 in g...       12/12/2012
# 64  Our next workshop is scheduled for February 15...       15/02/2022
# 65  The submission deadline, noted as 08/31/2021, ...       31/08/2021
# 67  We celebrate Independence Day on the 4th of Ju...       04/07/2022
# 69  The new year's celebration begins on 01-01-202...       01/01/2023
# 70  We scheduled the seminar for 03/14/2022, don't...       14/03/2022
# 71  My final working day here is noted as 31.08.2020.       31/08/2020
# 73  The holiday vacation starts on Dec 20th, 2021,...       20/12/2021
# 75            They officially moved in on 12/25/2019.       25/12/2019
# 76  Our festival starts on March 17, 2022, with a ...       17/03/2022
# 77          The ceremony date is fixed as 11.11.2021.       11/11/2021
# 79      Her graduation day is set for May 30th, 2022.       30/05/2022
# 81   The job interview is on 1/2/2022, don't be late.       01/02/2022
# 85  The official opening date is 10/10/2018, as pe...       10/10/2018
# 87  The New Year's Eve party is on 31-12-2022, joi...       31/12/2022
# 88  The next workshop is on February 29, 2024, due...       29/02/2024
# 89  Vacation officially starts on 07/15/2021, get ...       15/07/2021
# 91  The tournament begins on June 1st, 2021, early...       01/06/2021
# 92       The registration closing date is 08/08/2020.       08/08/2020
# 94  The exam will be held on 01.01.2022, start pre...       01/01/2022
#
#          Parsed Date
# 0      March/05/None
# 1         1990/08/07
# 5         2022/04/02
# 6               None
# 8               None
# 9      April/03/None
# 13              None
# 14    February/15/th
# 15        2021/31/08
# 19              None
# 20        2022/14/03
# 21        2020/08/31
# 23         Dec/20/th
# 25        2019/25/12
# 26     March/17/None
# 27        2021/11/11
# 29         May/30/th
# 31         2022/02/1
# 35        2018/10/10
# 37              None
# 38  February/29/None
# 39        2021/15/07
# 41        June/01/st
# 42        2020/08/08
# 44        2022/01/01
# 50              None
# 51     March/05/None
# 52        1990/08/07
# 56        2022/04/02
# 57              None
# 59              None
# 60     April/03/None
# 63              None
# 64    February/15/th
# 65        2021/31/08
# 67              None
# 69              None
# 70        2022/14/03
# 71        2020/08/31
# 73         Dec/20/th
# 75        2019/25/12
# 76     March/17/None
# 77        2021/11/11
# 79         May/30/th
# 81         2022/02/1
# 85        2018/10/10
# 87              None
# 88  February/29/None
# 89        2021/15/07
# 91        June/01/st
# 92        2020/08/08
# 94        2022/01/01

# %% [markdown]
# # #Overall Performance:
# Total Cases Analyzed: The function processed a total of 100 rows (48 correctly parsed, 52 incorrectly parsed).
# Correctly Parsed Dates: 48 cases were correctly parsed, meaning the function correctly identified and formatted the dates as expected.
# Incorrectly Parsed Dates: 52 cases were incorrectly parsed, where the function failed to extract or format the dates accurately.

# %%
# Visualize the comparison between expected and parsed dates
correct_rows = df[df['Match'] == True]
print(f"\nNumber of correctly parsed rows: {len(correct_rows)}")
print("\nCorrectly parsed dates:")
print(correct_rows[['Input', 'Expected Output', 'Parsed Date']])
# Out:
# Number of correctly parsed rows: 48
#
# Correctly parsed dates:
#                                                 Input Expected Output  \
# 2                         The deadline is 2022-12-31.      31/12/2022
# 3                      We met on 1st of January 2000.      01/01/2000
# 4   The concert is scheduled for 15th September, 2...      15/09/2021
# 7                          He was born on 1987/11/23.      23/11/1987
# 10  Her birthdate, noted as 1997-05-20, is in the ...      20/05/1997
# 11      Her appointment is on the 2nd of March, 2021.      02/03/2021
# 12                       The exam date is 2021.11.10.      10/11/2021
# 16                The course starts on 1st July 2023.      01/07/2023
# 17          Independence Day is on 4th of July, 2022.      04/07/2022
# 18                        His birthday is 1995/10/30.      30/10/1995
# 22                        The due date is 2020-02-28.      28/02/2020
# 24       The conference will be held on 5th May 2023.      05/05/2023
# 28                        The event is on 2023/07/04.      04/07/2023
# 30                    The release date is 2021-09-09.      09/09/2021
# 32                  The celebration is on 2022-10-10.      10/10/2022
# 33             His wedding is on 6th of August, 2020.      06/08/2020
# 34                    She was born on 3rd March 1998.      03/03/1998
# 36                        The deadline is 2020.12.15.      15/12/2020
# 40              The application is due by 2022-03-03.      03/03/2022
# 43                      The concert is on 2020/09/09.      09/09/2020
# 45                    Independence Day is 2023-07-04.      04/07/2023
# 46               The last date is 30th November 2022.      30/11/2022
# 47            The conference is on 15th October 2023.      15/10/2023
# 48                       His birthdate is 1990-05-20.      20/05/1990
# 49               The festival is on 12th August 2024.      12/08/2024
# 53  The deadline, unfortunately, is set to 2022-12...      31/12/2022
# 54  We first met on the 1st of January 2000 at the...      01/01/2000
# 55  The concert, happening on 15th September 2021,...      15/09/2021
# 58  His birth date, recorded as 1987/11/23, was a ...      23/11/1987
# 61  Their anniversary is marked on the 2nd of Marc...      02/03/2021
# 62  The official exam date is now 2021.11.10, per ...      10/11/2021
# 66     The course officially begins on 1st July 2023.      01/07/2023
# 68  He mentioned that his birth date is 1995/10/30...      30/10/1995
# 72   The project's due date is officially 2020-02-28.      28/02/2020
# 74  The conference, marked for 5th May 2023, is a ...      05/05/2023
# 78  The big event is planned for 2023/07/04, so ma...      04/07/2023
# 80   The software release date is set for 2021-09-09.      09/09/2021
# 82  The grand celebration is on 2022-10-10, a date...      10/10/2022
# 83  The wedding is on 6th of August, 2020, in the ...      06/08/2020
# 84  She mentioned she was born on the 3rd of March...      03/03/1998
# 86  The critical deadline is 2020.12.15, please no...      15/12/2020
# 90     The application submission date is 2022-03-03.      03/03/2022
# 93     The music concert is scheduled for 2020/09/09.      09/09/2020
# 95  We celebrate Independence Day on 2023-07-04, a...      04/07/2023
# 96  The final date for submission is 30th November...      30/11/2022
# 97  The annual conference is on 15th October 2023,...      15/10/2023
# 98  His birthdate, noted as 1990-05-20, is in the ...      20/05/1990
# 99  The festival will be celebrated on 12th August...      12/08/2024
#
#    Parsed Date
# 2   31/12/2022
# 3   01/01/2000
# 4   15/09/2021
# 7   23/11/1987
# 10  20/05/1997
# 11  02/03/2021
# 12  10/11/2021
# 16  01/07/2023
# 17  04/07/2022
# 18  30/10/1995
# 22  28/02/2020
# 24  05/05/2023
# 28  04/07/2023
# 30  09/09/2021
# 32  10/10/2022
# 33  06/08/2020
# 34  03/03/1998
# 36  15/12/2020
# 40  03/03/2022
# 43  09/09/2020
# 45  04/07/2023
# 46  30/11/2022
# 47  15/10/2023
# 48  20/05/1990
# 49  12/08/2024
# 53  31/12/2022
# 54  01/01/2000
# 55  15/09/2021
# 58  23/11/1987
# 61  02/03/2021
# 62  10/11/2021
# 66  01/07/2023
# 68  30/10/1995
# 72  28/02/2020
# 74  05/05/2023
# 78  04/07/2023
# 80  09/09/2021
# 82  10/10/2022
# 83  06/08/2020
# 84  03/03/1998
# 86  15/12/2020
# 90  03/03/2022
# 93  09/09/2020
# 95  04/07/2023
# 96  30/11/2022
# 97  15/10/2023
# 98  20/05/1990
# 99  12/08/2024

# %% [markdown]
# # Patterns in Incorrectly Parsed Dates:
# Looking at the incorrect results, several patterns and issues emerge:
#
# Month Names Handling:
#
# Example: "The event will take place on March 5, 2023." was parsed as "March/05/None". The function failed to convert the month name "March" to its numerical representation ("03").
# Cause: The current regex pattern or the month_name_to_number function isn't robust enough to handle all formats, particularly when the month name appears without additional context (like "March 5, 2023").
# Ambiguous Date Formats:
#
# Example: "Her birthday is on 07/08/1990." was correctly parsed, but in the case of "Submit your report by 08/31/2021.", it was incorrectly parsed as "2021/31/08".
# Cause: The function may misinterpret month and day positions due to the ambiguity in the formats (MM/DD/YYYY vs. DD/MM/YYYY).
# Edge Cases in Shortened Year Formats:
#
# Example: "They got married on 12/12/12." returned None. The function might not correctly interpret shortened year formats like "12" (meaning 2012).
# Cause: Lack of logic to handle two-digit years.
# Ordinal Indicators and Suffixes:
#
# Example: "The holiday starts on Dec 20th, 2021." was parsed as "Dec/20/th".
# Cause: The regex captures ordinal indicators like "th" but fails to handle them properly in the final output.
# 3. Correctly Parsed Dates:
# The correctly parsed dates mostly involve straightforward and unambiguous formats, such as:
#
# YYYY-MM-DD formats: "The deadline is 2022-12-31." -> "31/12/2022".
# Day-Month-Year with ordinals: "We met on 1st of January 2000." -> "01/01/2000".
# Dates without ordinals: "The official exam date is now 2021.11.10." -> "10/11/2021".
# These cases demonstrate that the function works well with clear, unambiguous, and common date formats.
